# %%
n=17

# %%
flag=True

# %%
for i in range(2,n):
    if n%i==0:
        flag=False
        break
print(f"{n} is a prime number" if  flag else  f"{n} is not  a prime number")
# Out:
# 17 is a prime number

# %%
# print prime number upto nth value

n=10
for i in range(2,n+1):
    is_prime=True
    for j in range(2,i):
        if i%j==0:
            is_prime=False
            break
    if is_prime:
        print(i)
# Out:
# 2
# 3
# 5
# 7
