# %% [markdown]
# Standard Library Overview
#
# Python's Standard Library is a vast collection of modules and packages that come bundled with python,providing a wide range of functionalities out of the box.Here's an overview of some of the most commonly used modules and packages in the python standard library.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 4
# cherry

# %%
#### File and directory access
import os
print(os.getcwd())
# Out:
# d:\Data_engineering\Python_DE\5.Modules\package

# %%
os.mkdir('test_dir')

# %%
os.rmdir('test_dir')

# %%
## High level operation on files and collection of files

import shutil
shutil.copyfile(r'D:\pythonDe\python_material\test.py',r'D:\pythonDe\python_material\test_cp.py')
# Out:
# 'D:\\pythonDe\\python_material\\test_cp.py'

# %%
import json 
data={'name':'jyothi','age':'34'}
json_str= json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "jyothi", "age": "34"}
# <class 'str'>
# {'name': 'jyothi', 'age': '34'}
# <class 'dict'>

# %%
### csv

import csv

with open('example.csv',mode='w',newline='') as file:
    writer= csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['jyothi',34])
    writer.writerow(['korra',35])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['jyothi', '34']
# ['korra', '35']

# %%
## datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-02-06 21:48:32.328262
# 2026-02-05 21:48:32.328262

# %%
## time

import time
print(time.time())
time.sleep(5)
print(time.time())
# Out:
# 1770394836.3555746
# 1770394841.3566184

# %%
## regular expression
import re
pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123

# %% [markdown]
# Conclusion:
#
# Python's Standard Library is extensive and provided tools for almost any task you can think of,from file handling  to web services,from data serialization to concurrent execution.Familiarizing yourself with the modules and packages available in the standard library can significantly enhance your ability to write efficient and effective python programs.
