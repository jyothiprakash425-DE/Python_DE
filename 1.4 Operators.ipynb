# %% [markdown]
# Operators:
#
# 1. Arthimetic Operators: Addition,Substraction,Multiplication,Division,Floor division,Modulus,Exponentiation
# 2.Comparision operatorss: Equal to ,Not equal to,greater than,lessa than ,greater than or equal to ,Less than or equal to
# 3.Logical Operators:And .Or,Not

# %%
## Arthimetic operation

a=10
b=5

add_result=a+b # addition
sub_result=a-b #substraction
mul_result=a*b #multiplication
div_result=a/b  # division
floor_div_result=a//b # floor division
modulus_result=a%b #modulus operation
exponent_result=a**b #Exponentiation

print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
10/5
# Out:
# 2.0

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %% [markdown]
# Comparision Operators

# %%
## comparision operator
## == Equal to

a=10
b=10

a==b
# Out:
# True

# %%
str1="jyothi"
str2="jyothi"

str1==str2
# Out:
# True

# %%
# Not equal to

str1!=str2
# Out:
# False

# %%
str3="jyothi"
str4="jyothi"

str3!=str4
# Out:
# False

# %%
#greater than >

num1=45
num2=55
num1>num2
# Out:
# False

# %%
#less than <

num1=45
num2=55
num1<num2
# Out:
# True

# %%
#greater than or equal to >=

num1=45
num2=45
num1>=num2
# Out:
# True

# %%
# less than or equal to <=

num1=45
num2=45
num1<=num2
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
### And,Not OR

x=True;y=True

result= x and y
print(result)
# Out:
# True

# %%
#or
x=True;y=False

result= x or y
print(result)
# Out:
# True

# %%
#Not operator
x=True
not x
# Out:
# False

# %%
# Simple calculator

num1=10
num2=5

add_result=num1 + num2 # addition
sub_result=num1-num2 #substraction
mul_result=num1*num2 #multiplication
div_result=num1/num2  # division
floor_div_result=num1//num2 # floor division
modulus_result=num1%num2 #modulus operation
exponent_result=num1**num2 #Exponentiation

print("addition:",add_result)
print("substraction:",sub_result)
print("multiplication:",mul_result)
print("didision:",div_result)
print("Fllor division",floor_div_result)
print("Modulus operation",modulus_result)
print("Exponentiation",exponent_result)
# Out:
# addition: 15
# substraction: 5
# multiplication: 50
# didision: 2.0
# Fllor division 2
# Modulus operation 0
# Exponentiation 100000
