# %% [markdown]
# Syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structured programs in a language.In simple terms ,syntax is about the correct arrangement of words and symbols in a code.
#
# Semantics refers to the meaning or the interpretation of the symbols ,charecters and commands in a language.It is abiut what the code is suppoerted to do when it runs

# %%
## Basic Syntax Rules in Python
## case Sensitivity-Python is case sensitive

name="jyothi"
Name="prakash"
print(name)
print(Name)
# Out:
# jyothi
# prakash

# %% [markdown]
# Indentation
#
# Indentation in python is used to define the structure and hierarchy of the code.Unlike any other programming languages that use braces{} to delimit blocks of code,Python uses Identation to determine the grouping of statements.This means that all the statement within a block must be indented at the same level

# %%
##Indentation
## Python uses indentation to define blocks of code.Consistent use of spaces (commonly 4) or tab is required.

age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
#This is a single line comment
print("Hello world")
# Out:
# Hello world

# %%
##Line continuation
##use a backslash(\) to continue a statment to the next line.

total=2+4+5+7\
+9+10\
+11

print(total)
# Out:
# 48

# %%
#multi line statements on a single-line
x=5;y=10;z=20;w=x+y+z
print(w)
# Out:
# 35

# %%
#understand semantics in python
#variable Assignment

age=32 ## age is an integer
name="jyothi" ## name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
#type interface
variable=10
print(type(variable))
variable="jyothi"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
##code example of indentation
if True:
    print("correct Indentation")
    if False:
        print("This not print")
    print("This will print")
print("outside the if block")
# Out:
# correct Indentation
# This will print
# outside the if block

# %% [markdown]
# Conclusion:
#
# Understanding the syntax and semantics of python is crucial for writing correct and meaning programs.Syntax ensures the code is properly structured,while semantics ensures the code behaves as expected>Mastering these concepts will help in writing efficient and error-free python code.
